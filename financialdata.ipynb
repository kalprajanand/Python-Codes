# %% [markdown]
# <a href="https://colab.research.google.com/github/kalprajanand/Python-Codes/blob/main/financialdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ***python p[andas practice***

# %%
df= pd.read_csv('/Original_data.csv')

# %%
df
# Out:
#     GENDER  AGE Do you invest in Investment Avenues?  \
# 0   Female   34                                  Yes
# 1   Female   23                                  Yes
# 2     Male   30                                  Yes
# 3     Male   22                                  Yes
# 4   Female   24                                   No
# 5   Female   24                                   No
# 6   Female   27                                  Yes
# 7     Male   21                                  Yes
# 8     Male   35                                  Yes
# 9     Male   31                                  Yes
# 10  Female   35                                  Yes
# 11    Male   29                                  Yes
# 12  Female   21                                   No
# 13  Female   28                                  Yes
# 14  Female   25                                  Yes
# 15    Male   27                                  Yes
# 16  Female   28                                  Yes
# ...

# %% [markdown]
# there is no. of pandas commands to read other data formats:
# # pd.read_excel('myfile.xlsx',sheet_name='sheet1', index_col=None, na_values=['NA'])
# #pd.read_stata('myfile.dta')
# # pd.read_sas('myfile.sas7bdat')
# #pd.read_hdf('myfile.h5','df)

# %%
#list First 5 Records from data
df.head()
# Out:
#    GENDER  AGE Do you invest in Investment Avenues?  \
# 0  Female   34                                  Yes
# 1  Female   23                                  Yes
# 2    Male   30                                  Yes
# 3    Male   22                                  Yes
# 4  Female   24                                   No
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]  \
# 0                                                  1
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  2
#
#    What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]  \
# 0                                                  2
# 1                                                  3
# ...

# %%
df.tail()
# Out:
#    GENDER  AGE Do you invest in Investment Avenues?  \
# 35   Male   30                                  Yes
# 36   Male   30                                  Yes
# 37   Male   25                                  Yes
# 38   Male   31                                  Yes
# 39   Male   29                                  Yes
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]  \
# 35                                                  1
# 36                                                  2
# 37                                                  5
# 38                                                  2
# 39                                                  4
#
#     What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]  \
# 35                                                  4
# 36                                                  4
# ...

# %%
ds=pd.read_csv('/Salaries.csv')

# %%
ds
ds.head()
ds.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
ds.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
ds.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %% [markdown]
# data frame =data structure
# **handling of the data in data frame**
#
# Panda type              Native python type
#
# Object                   String
#
# int64                     int
#
# float64                  float
#
# datetime64,timedelta[ns]  N/A ( the datetime module in python's
#  standard library)

# %%
#check a prticular column type
ds['salary'].dtype
# Out:
# dtype('int64')

# %%
#check types of data for all columns
ds.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# Data Frames Attributes = high level info of data is attributes
#
#  df.attributes
# 1. dtypes--- list the types of columns
# 2. columns--- list the columns name
# 3. axes----- list the row and column na,e
# 4. ndim----- number of dimensions
# 5. size----- no. of elements
# 6. shape---- return a tuple representing the dimensionality
# 7. values-- numpy representation of the data

# %%
ds.shape
# Out:
# (78, 6)

# %%
df.shape
# Out:
# (40, 24)

# %%
df.size
# Out:
# 960

# %%
df.size
# Out:
# 960

# %%
ds.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
ds.values # array reperesentation of the dta
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
ds.ndim # dimension of the data
# Out:
# 2

# %%
#find how many records this data frame has?
ds.shape[0]
# Out:
# 78

# %%
#how many columns are there?
ds.shape[1]
# Out:
# 6

# %%
# whta are the column names?
ds.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#what types of columns we have in this data frame
ds.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
ds.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=40, step=1),
#  Index(['GENDER', 'AGE', 'Do you invest in Investment Avenues?',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Mutual Funds]',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Equity Market]',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Debentures]',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Government Bonds]',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Fixed Deposits]',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Public Provident Fund]',
#         'What do you think are the best options for investing your money? (Rank in order of preference) [Gold]',
# ...
